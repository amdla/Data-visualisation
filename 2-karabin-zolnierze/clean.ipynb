# %%
import pandas as pd

df = pd.read_csv('baza_danych.csv')
df.columns = df.columns.str.strip()

df
# Out:
#       Nazwisko ↑Nazwisko Imię (imiona)Imię (imiona)  \
# 0                 Ababow                      Abłaj
# 1                Abaksyn                     Radjan
# 2               Abakumow                      Wasyl
# 3               Abakumow                    Wasilij
# 4                  Abduł                    Aptołaj
# ...                  ...                        ...
# 11415               Zyła                      Paweł
# 11416        Zyliskowicz                    Mikołaj
# 11417             Żyljow                    Wasilij
# 11418              Żyłko                     Wasyli
# 11419           Zytyniow                      Paweł
#
#       Nazwa formacji/jednostki wojskowejNazwa formacji/jednostki wojskowej  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# ...

# %%
import pandas as pd

df = pd.read_csv('cleaned_baza_danych.csv')

df.columns = df.columns.str.strip()
 
df
# Out:
#       Nazwisko ↑Nazwisko Imię (imiona)Imię (imiona)  \
# 0                 Ababow                      Abłaj
# 1                Abaksyn                     Radjan
# 2               Abakumow                      Wasyl
# 3               Abakumow                    Wasilij
# 4                  Abduł                    Aptołaj
# ...                  ...                        ...
# 10947               Zyła                      Paweł
# 10948        Zyliskowicz                    Mikołaj
# 10949             Żyljow                    Wasilij
# 10950              Żyłko                     Wasyli
# 10951           Zytyniow                      Paweł
#
#       Nazwa formacji/jednostki wojskowejNazwa formacji/jednostki wojskowej  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# ...

# %%
import pandas as pd

df = pd.read_csv('cleaned_baza_danych.csv')

df.columns = df.columns.str.strip()

new_column_names = [
    "Nazwisko",
    "Imie",
    "Nazwa formacji",
    "Nazwa obozu / miejsca internowania",
    "Data zgonu",
    "Miejsce zgonu",
    "Miejsce pochówku",
    "Archiwum"
]

df.columns = new_column_names

df.to_csv('baza_danych_renamed.csv', index=False)
# Out:
# Column names updated and saved to 'baza_danych_renamed.csv'

# %%
df
# Out:
#           Nazwisko     Imie                Nazwa formacji  \
# 0           Ababow    Abłaj                           NaN
# 1          Abaksyn   Radjan                           NaN
# 2         Abakumow    Wasyl                           NaN
# 3         Abakumow  Wasilij                           NaN
# 4            Abduł  Aptołaj                           NaN
# ...            ...      ...                           ...
# 10947         Zyła    Paweł                           NaN
# 10948  Zyliskowicz  Mikołaj                           NaN
# 10949       Żyljow  Wasilij  149 pułk piechoty 3 kompania
# 10950        Żyłko   Wasyli                           NaN
# 10951     Zytyniow    Paweł                           NaN
#
#       Nazwa obozu / miejsca internowania  Data zgonu      Miejsce zgonu  \
# 0                                    NaN  1919-11-25    Brześć Litewski
# 1                                    NaN  1921-01-03               Lida
# ...
